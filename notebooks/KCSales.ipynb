# %% [markdown]
# #### Extracting big data from the King County Assessor regarding home sales prices
#     - Block group
#     - Sale price
#     - Date of sale
#     - Year of sale

# %%
import pandas as pd
import numpy as np

# %%
# Path will varie within different directory 
df = pd.read_csv('data/EXTR_RPSale.csv', low_memory=False)

# %%
df.head(5)
# Out:
#    ExciseTaxNbr   Major Minor DocumentDate  SalePrice    RecordingNbr Volume  \
# 0       2687551  138860  0110   08/21/2014     245000  20140828001436
# 1       1235111  664885  0040   07/09/1991          0  199203161090      071
# 2       2704079  423943  0050   10/11/2014          0  20141205000558
# 3       2584094  403700  0715   01/04/2013          0  20130110000910
# 4       1056831  951120  0900   04/20/1989      85000  198904260448      117
#
#   Page PlatNbr PlatType     ...     PropertyType PrincipalUse SaleInstrument  \
# 0                           ...                3            6              3
# 1  001  664885        C     ...                3            0             26
# 2                           ...                3            6             15
# 3                           ...                3            6             15
# 4  053  951120        P     ...                3            0              2
#
#   AFForestLand  AFCurrentUseLand  AFNonProfitUse  AFHistoricProperty  \
# 0            N                 N               N                   N
# 1            N                 N               N                   N
# 2            N                 N               N                   N
# 3            N                 N               N                   N
# 4            N                 N               N                   N
#
#   SaleReason PropertyClass SaleWarning
# 0          1             8
# 1         18             3          11
# 2         18             8    18 31 51
# 3         11             8    18 31 38
# 4          1             9          49
#
# [5 rows x 24 columns]

# %%
# Filtering for Major, Minor, SalePrice, DocumentDate, PropertyType
df = df.filter(items=['Major', 'Minor', 'SalePrice','DocumentDate', 'PropertyType' ])
df.head(5)
# Out:
#     Major Minor  SalePrice DocumentDate  PropertyType
# 0  138860  0110     245000   08/21/2014             3
# 1  664885  0040          0   07/09/1991             3
# 2  423943  0050          0   10/11/2014             3
# 3  403700  0715          0   01/04/2013             3
# 4  951120  0900      85000   04/20/1989             3

# %%
# Filtering for sale price greater than $0
df_filtered = df.query('SalePrice>=1')
df_filtered.head(5)
# Out:
#     Major Minor  SalePrice DocumentDate  PropertyType
# 0  138860  0110     245000   08/21/2014             3
# 4  951120  0900      85000   04/20/1989             3
# 6  022209  9001    5755000   04/25/2001             1
# 7  022209  9003    5755000   04/25/2001             1
# 8  022209  9007    5755000   04/25/2001             1

# %%
# Filtering for single family home sales (Property type  = 11)
filteredData = df_filtered.query('PropertyType == 11')

# %%
filteredData.head(5)
# Out:
#       Major Minor  SalePrice DocumentDate  PropertyType
# 313  221250  0090     400000   04/12/2017            11
# 339  701120  1162     725000   11/02/2016            11
# 395  732190  0030    1000000   01/25/2018            11
# 580  799960  0065       5000   04/13/2011            11
# 679  277060  6955     607500   07/06/2017            11

# %%
# Joining Major + Minor to create ParcelID
ParcelId = filteredData.apply(lambda x:'%s-%s' % (x['Major'],x['Minor']),axis=1)
ParcelID = pd.DataFrame(data=ParcelId, columns=['PercelID'])
ParcelID.head(5)
# Out:
#         PercelID
# 313  221250-0090
# 339  701120-1162
# 395  732190-0030
# 580  799960-0065
# 679  277060-6955

# %%
KCSales = pd.concat([filteredData, ParcelID], sort=True)
KCSales.head(10)
# Out:
#      DocumentDate   Major Minor PercelID  PropertyType  SalePrice
# 313    04/12/2017  221250  0090      NaN          11.0   400000.0
# 339    11/02/2016  701120  1162      NaN          11.0   725000.0
# 395    01/25/2018  732190  0030      NaN          11.0  1000000.0
# 580    04/13/2011  799960  0065      NaN          11.0     5000.0
# 679    07/06/2017  277060  6955      NaN          11.0   607500.0
# 685    08/01/2016  382220  0136      NaN          11.0   405000.0
# 727    05/10/2017  231000  0480      NaN          11.0   410000.0
# 965    02/26/2018  785336  0400      NaN          11.0   850000.0
# 1092   05/03/2018  401380  0208      NaN          11.0       10.0
# 1105   04/20/2017  073220  0010      NaN          11.0   289740.0

# %% [markdown]
# #### Extracting Centroid using pysal to extract the geographic center points of the coordinates

# %%
import pysal as ps 
import xml.etree.ElementTree as ET
import urllib.request

# %%
# Path will change within different directory 
inputfile = "data\parcel\parcel.shp"

# %%
# Reading shapefile via pysal 
df_Shapefile = ps.pdio.read_files(inputfile)
df_Shapefile.head(5)
# Out:
#     MAJOR MINOR         PIN     Shape_area    Shape_len  \
# 0  000020  0001  0000200001  367523.511641  4889.923177
# 1  000020  0003  0000200003    5446.331001   330.703378
# 2  000020  0006  0000200006    6000.064502   340.002037
# 3  000020  0007  0000200007    7200.080077   360.002087
# 4  000020  0008  0000200008    6068.041700   317.359849
#
#                                             geometry
# 0  <pysal.cg.shapes.Polygon object at 0x000000001...
# 1  <pysal.cg.shapes.Polygon object at 0x000000001...
# 2  <pysal.cg.shapes.Polygon object at 0x000000001...
# 3  <pysal.cg.shapes.Polygon object at 0x000000001...
# 4  <pysal.cg.shapes.Polygon object at 0x000000001...

# %%
# Convert to Lat/Long (from state plane coordinates)
def XYtoLatLong(X, Y):
    URL = "http://citygis/coordinateconversion/coordinateconversion.asmx/WaStatePlaneToLatLong?X=" + str(X) + "&Y=" + str(Y)
    tree = ET.parse(urllib.request.urlopen(URL))
    doc = tree.getroot()
    return (float(doc[0].text), float(doc[1].text))

# %%
# Iterate over each parcel to get Lat/Long
Latitude = []
Longitude = []

for index, row in df_Shapefile.iterrows():   
        X = row['geometry'].centroid[0]
        Y = row['geometry'].centroid[1]
        Coordinates = XYtoLatLong(X,Y)
        Latitude.append(Coordinates[0])
        Longitude.append(Coordinates[1])

df_Shapefile['lat'] = Latitude
df_Shapefile['lon'] = Longitude

# %%
#df_shapefile.head(5)

# %%
df_kcsales = pd.read_csv('KCSales.csv')

# %%
df_kcsales.head(-5)
# Out:
#        Unnamed: 0   Major  Minor  SalePrice DocumentDate  PropertyType  \
# 0               0  221250     90     400000   04/12/2017            11
# 1               1  701120   1162     725000   11/02/2016            11
# 2               2  732190     30    1000000   01/25/2018            11
# 3               3  799960     65       5000   04/13/2011            11
# 4               4  277060   6955     607500   07/06/2017            11
# 5               5  382220    136     405000   08/01/2016            11
# 6               6  231000    480     410000   05/10/2017            11
# 7               7  785336    400     850000   02/26/2018            11
# 8               8  401380    208         10   05/03/2018            11
# 9               9   73220     10     289740   04/20/2017            11
# 10             10  928480   1200     355000   07/12/2017            11
# 11             11  363017     60     756000   09/15/2016            11
# 12             12  335640   7476     215000   10/23/2017            11
# 13             13  144288     80     614950   08/10/2016            11
# 19     8944750010  47.49199 -122.16943
# 20      471200060       NaN        NaN
# 21     1823099082  47.48314 -121.70745
# 22      731500180  47.35931 -122.20065
# 23     1137500030  47.58461 -122.05733
# 24      579000563  47.70069 -122.38620
# 25     2258500015  47.60833 -122.30793
# 26      809001565  47.63515 -122.35226
# 27     2211700075  47.56276 -122.11774
# 28     4187200290  47.51399 -122.15372
# 29     7702100080  47.66096 -122.02340
# ...           ...       ...        ...
# 41440  2937500030  47.70710 -122.12602
# 41441  7384700290  47.58233 -122.06667
# 41442  8031700246  47.68325 -122.32313
# 41443   797000041  47.49918 -122.32419
# 41444  1025039180  47.67305 -122.40281
# 41445  2767602016  47.67397 -122.38150
# 41446  2872101240  47.68145 -122.39509
# 41447  3879901246  47.62637 -122.36162
# 41448  5557300170  47.31785 -122.34968
# 41449  6868200090  47.71340 -122.30350
# 41450  6791050420  47.57999 -122.05572
# 41451  7950304215  47.56269 -122.28139
# 41452  1387301620  47.73683 -122.19363
# 41453  1545300370  47.61134 -122.05689
# 41454  2922059211  47.36315 -122.20515
# 41455  3332000685  47.54993 -122.27454
# 41456  9290860260  47.51033 -122.19254
# 41457  2008000520  47.40974 -122.31332
# 41458  7985400135  47.53383 -122.36088
# 41459  6752500050  47.54458 -122.12201
# 41460  4027700843  47.76976 -122.26869
# 41461  8934600030  47.67924 -122.27729
# 41462   323079084  47.50296 -121.89851
# 41463  3622069049  47.35320 -121.98279
# 41464  1123049161  47.49536 -122.25187
# 41465  3629950060  47.54767 -122.00365
# 41466  3388110380  47.49613 -122.31999
# 41467  1241500067  47.67062 -122.17131
# 41468   820079066  47.22859 -121.93630
# 41469  2025059181  47.63400 -122.20327
#
# [41470 rows x 9 columns]

# %%
# Filtering for sale price greater than $0
df_kcsales = df_kcsales.query('SalePrice>=100000')

# %%
df_kcsales = df_kcsales.dropna()
#df_kcsales.head(-5)

# %%
df_kcsales = df_kcsales.drop(['Major', 'Minor' ], axis=1)

# %%
df_kcsales.head(5)
# Out:
#    Unnamed: 0  SalePrice DocumentDate  PropertyType    ParcelID       lat  \
# 0           0     400000   04/12/2017            11  2212500090  47.33645
# 1           1     725000   11/02/2016            11  7011201162  47.63718
# 3           3       5000   04/13/2011            11  7999600065  47.47379
# 4           4     607500   07/06/2017            11  2770606955  47.65817
# 5           5     405000   08/01/2016            11  3822200136  47.72822
#
#          lon
# 0 -122.19687
# 1 -122.36817
# 3 -122.26811
# 4 -122.39068
# 5 -122.29669

# %%
df_kcsales = df_kcsales[['ParcelID', 'DocumentDate', 'PropertyType', 'SalePrice', 'lat', 'lon']]

# %%
df_kcsales.head(5)
# Out:
#      ParcelID DocumentDate  PropertyType  SalePrice       lat        lon
# 0  2212500090   04/12/2017            11     400000  47.33645 -122.19687
# 1  7011201162   11/02/2016            11     725000  47.63718 -122.36817
# 3  7999600065   04/13/2011            11       5000  47.47379 -122.26811
# 4  2770606955   07/06/2017            11     607500  47.65817 -122.39068
# 5  3822200136   08/01/2016            11     405000  47.72822 -122.29669

# %%
df_kcsales_blkgrps.to_csv('KCSales.csv', index=False)
